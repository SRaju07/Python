# %%
#1.Find the error in the following Python code:

for i in range(5): # colon missing
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = 5 # numbers should not enter in double codes("5")
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
    return a + b

# %%
add_numbers(a,b)
# Out:
# 15

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print(numbers[3]) # there is no index as number 4
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print ("Hello, World!") # Bracket missing
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0 # ZeroDivisionError: division by zero
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 #6.Find the error in the following Python code:
# ----> 2 x = 5 / 0
#
# ZeroDivisionError: division by zero

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)
# Name is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 #7.Find the error in the following Python code:name = "Alice"
#       2 age = 25
# ----> 3 print("Name: " + name + ", Age: " + age)
#
# NameError: name 'name' is not defined

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)
# A negative step counts downward, but you are trying to count from 1 to 10, which requires a positive step.

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5: # in if condition need to compare, so correct one is x==5
    print("x is 5")
# Out:
#   Cell In[19], line 3
#     if x = 5:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#10. Identify the error in the following function definition:

def greet(name) # colon missing
    print("Hello, " + name)
# Out:
#   Cell In[23], line 3
#     def greet(name)
#                    ^
# SyntaxError: expected ':'
