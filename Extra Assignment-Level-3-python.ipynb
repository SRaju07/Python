# %%
i=10
print("value : " , i)
if(i==10):
    print("correct")
# Out:
# value :  10
# correct

# %%
cred=input("Enter your password : ")
print(cred)
print("Your password is correct")
# Out:
# Enter your password :  Hope@123
# Hope@123
# Your password is correct

# %%
a=20
print("Age : " , a)
if(a==20):
    print("Adult")
# Out:
# Age :  20
# Adult

# %%
num=int(input("Enter any number : "))
print(num)
print("Positive")
# Out:
# Enter any number :  1
# 1
# Positive

# %%
num=int(input("Enter a number to check : "))
print(num)
if(num%5==0):
    print("No. is divisible by 5")
else:
    print("No. is not divisble by 5")
# Out:
# Enter a number to check :  55
# 55
# No. is divisible by 5
