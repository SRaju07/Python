# %%
print("Welcome to Asssignment-1")
# Out:
# Welcome to Asssignment-1

# %%
Num1=10
Num2=30
add=Num1+Num2
print(add)
# Out:
# 40

# %%
weight=float(input("Enter the BMI Index : "))
if(weight<18.5):
    print("Under Weight")
elif(weight>18.5 and weight<24.9):
    print("Normal Weight")
elif(weight>24.9 and weight<29.9):
    print("Over Weight")
else:
    print("Obese")
# Out:
# Enter the BMI Index :  27.63
# Over Weight
